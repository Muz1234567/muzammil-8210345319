# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset("flights")

# %%
data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
x=data.set_index('month')

# %%
plt.figure(figsize=(30,30))
sns.heatmap(x,cmap='coolwarm',annot=True,linewidth=1)
# Out:
# <Axes: ylabel='month'>

# %%
x.head(4)
# Out:
#        year  passengers
# month
# Jan    1949         112
# Feb    1949         118
# Mar    1949         132
# Apr    1949         129

# %%
sns.heatmap(x.head(4),cmap='coolwarm',annot=True,linewidth=3)
# Out:
# <Axes: ylabel='month'>

# %%
#in the above there is large amount of data so we have to plot heat map in normal size data.
