# %% [markdown]
# # Testing an API In Postman App

# %%
#first of all I have downloaded postman app from google and install it.

# %%
#Then i have copied url from google of shuffle deck card and paste in postman app.

# %%
#The we have sent request for creating an api and after API created we saved it in collection with name 'shuffle deck card'.

# %%
#After that we go to the collection named "shuffle deck" and run the collection and applied test for it.

# %%
#so after that we saw this kind of interface below in the image.

# %% [markdown]
# ![image.png](attachment:image.png)
