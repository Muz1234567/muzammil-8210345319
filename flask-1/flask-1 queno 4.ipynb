# %%
from flask import Flask

# %%
app=Flask(__name__)

# %%
@app.route("/welcome")
def test1():
    return "Welcome to ABC Corporation"

# %%
@app.route("/")
def test2():
    return ({"Company Name":"ABC Corporation",
            "Location":"India",
            "contact Detail":"999-999-9999"})

# %%
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.4:5000
# Press CTRL+C to quit
# 192.168.1.4 - - [04/Oct/2023 12:13:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Oct/2023 12:13:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Oct/2023 12:13:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Oct/2023 12:15:16] "GET /welcome HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Oct/2023 12:16:56] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![Screenshot%202023-10-04%20121635.png](attachment:Screenshot%202023-10-04%20121635.png)

# %% [markdown]
# ![Screenshot%202023-10-04%20121710.png](attachment:Screenshot%202023-10-04%20121710.png)

# %%
#so in this way with use of differnent roue name we are able to print .
