# %% [markdown]
# # Different Methods For Web Scraping

# %%
#Copy and paste
#HTML parsing
#DOM parsing
#Text pattern matching
#Computer vision web page analysis

# %%
#Copy and paste;Manually copying and pasting data from a web page into text file or spreadsheet is the most basic form of web scraping.

# %%
#HTML parsing;Many websites contain large collections of pages that are dynamically generated from an underlying structured source,such as database.

# %%
#Wrapper generation algorithms assume that input pages of a wrapper induction system follow a common template and can be identified using a URL common scheme.

# %%
#DOM parsing;Object model for documents,Programs can retrieve dynamic content generated by client side scripts by embedding a full-fledged web browser such as internet explorer or the Mozilla browser control.

# %%
#Text pattern matching;The UNIX grep command or regular expression matching facilities of programming languages can be used to extract information from webpages in simple way.

# %%
#Computer vision webpage analysis;There are efforts using machine learning and computer vision to identify and extract information from web pages by visually interpreting pages as a human would.
